# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

df=pd.read_csv("full_dataset_v3_170labels plus human revise_second.csv")
high_con_df=pd.read_csv('human_review - high_conf_v3.csv')
low_con_df=pd.read_csv('human_review - low_conf_v3.csv')

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 952           952         952
# 953           953         953
# 954           954         954
# 955           955         955
# 956           956         956
#
#                                                   text  label
# 0    First time mom here. My husband recently start...    0.0
# 1    I gained 80 pounds while I was pregnant I went...    1.0
# 2    i’m not usually one to ask for help when i nee...    0.0
# 3    I (31f) and my husband (34m) just had our firs...    0.0
# 4    Hi there, 28F with 2nd baby. 6 weeks PP and wa...    0.0
# ..                                                 ...    ...
# 952  I hit 7 months postpartum tomorrow, and I thin...    0.0
# 953  PPD sucks. I’m overwhelmed by everything. Even...    1.0
# 954  Hello! I’m a first time c section mom who’s 7 ...    0.0
# 955  I finally reached breaking point today. I thin...    0.0
# 956  hi everyone, I was just wondering if anyone ha...    NaN
#
# [957 rows x 4 columns]

# %%
low_con_df
# Out:
#        0  Unnamed: 1  Unnamed: 0  \
# 0      1         173         173
# 1      2         185         185
# 2      3         188         188
# 3      4         192         192
# 4      5         197         197
# ..   ...         ...         ...
# 101  102         914         914
# 102  103         915         915
# 103  104         943         943
# 104  105         948         948
# 105  106         949         949
#
#                                                   text  label  \
# 0    Has anyone been hospitalised in a (mbu) mother...    NaN
# 1    She committed me to a mental hospital after my...    NaN
# 2    I’m 8 weeks PP and a FTM. I’ve done fairly goo...    NaN
# 3    I’m 2 weeks post TMFR at 28 weeks due to letha...    NaN
# 4    I feel broken, I'm just a fraction of who I wa...    NaN
# ..                                                 ...    ...
# 101  I can’t fucking do this. I have a 2.5yo and a ...    NaN
# 102  I have been struggling with my body image sinc...    NaN
# 103  I (32f), started feeling ppd when baby was 7mo...    NaN
# 104  I don’t have any help and it’s starting to wei...    NaN
# 105  I miss my relationship. I miss myself. It feel...    NaN
#
#                                         processed_text  pseudo_label  \
# 0    anyone hospitalise mbu mother baby unit \n\n f...             0
# 1    commit mental hospital first child bear ob psy...             0
# 2    week pp ftm do fairly good come ppd start snea...             0
# 3    week post tmfr week due lethal fetal diagnosis...             1
# 4    feel broken fraction not know ever get back ev...             2
# ..                                                 ...           ...
# 101  can not fucking yo mo can not want run away wa...             0
# 102  struggle body image since son emergency c sect...             1
# 103  f start feel ppd baby month old think way easy...             1
# 104  not help starting weigh baby month old mil alw...             1
# 105  miss relationship miss feel like everything th...             0
#
#      confidence  human_label
# 0      0.542298            2
# 1      0.590330            0
# 2      0.571741            0
# 3      0.458345            2
# 4      0.456265            2
# ..          ...          ...
# 101    0.488476            0
# 102    0.532243            0
# 103    0.545722            0
# 104    0.458577            0
# 105    0.581253            0
#
# [106 rows x 9 columns]

# %%
high_con_df
# Out:
#      0  Unnamed: 1  Unnamed: 0  \
# 0    1         175         175
# 1    2         179         179
# 2    3         195         195
# 3    4         212         212
# 4    5         224         224
# ..  ..         ...         ...
# 82  83         890         890
# 83  84         905         905
# 84  85         913         913
# 85  86         929         929
# 86  87         936         936
#
#                                                  text  label  \
# 0   I’m 4 months PP and I’m still feeling this way...    NaN
# 1   I don’t know where I can vent so posting this ...    NaN
# 2   It’s been 1 yr and I’m still a mess. I just wi...    NaN
# 3   Every since I had my baby i can't stand my MIL...    NaN
# 4   Not sure if this is the right sub for this?\n\...    NaN
# ..                                                ...    ...
# 82  I have a history of mental health issues (depr...    NaN
# 83  My MIL treated me like shit after I had my 1st...    NaN
# 84  I need some help navigating an issue with my S...    NaN
# 85  I’m at the fucking ledge today…. But I’m talki...    NaN
# 86  This is something that has bugged me for ALONG...    NaN
#
#                                        processed_text  pseudo_label  \
# 0   month pp still feel way lose entire identity s...             1
# 1   not know vent post herei baby wks ago feel rag...             0
# 2   yr still mess wish could disappear wish husban...             0
# 3   every since baby can not stand mil never relat...             0
# 4   sure right sub \n\n anyone else work relate pp...             0
# ..                                                ...           ...
# 82  history mental health issue depression anxiety...             2
# 83  mil treat like shit st baby without doubt cont...             0
# 84  need help navigate issue sil talk therapist ma...             0
# 85  fucking ledge today talk not want daughter alm...             1
# 86  something bug along time wonder anyone else th...             1
#
#     confidence  human_label
# 0     0.802369          2.0
# 1     0.806413          0.0
# 2     0.867494          0.0
# 3     0.883543          0.0
# 4     0.800158          0.0
# ..         ...          ...
# 82    0.903879          NaN
# 83    0.831589          NaN
# 84    0.803161          NaN
# 85    0.880052          NaN
# 86    0.840490          NaN
#
# [87 rows x 9 columns]

# %%
low_con_filtered = low_con_df[['Unnamed: 1', 'text', 'human_label']]


low_con_filtered.set_index('Unnamed: 1', inplace=True)

# %%
low_con_filtered
# Out:
#                                                          text  human_label
# Unnamed: 1
# 173         Has anyone been hospitalised in a (mbu) mother...            2
# 185         She committed me to a mental hospital after my...            0
# 188         I’m 8 weeks PP and a FTM. I’ve done fairly goo...            0
# 192         I’m 2 weeks post TMFR at 28 weeks due to letha...            2
# 197         I feel broken, I'm just a fraction of who I wa...            2
# ...                                                       ...          ...
# 914         I can’t fucking do this. I have a 2.5yo and a ...            0
# 915         I have been struggling with my body image sinc...            0
# 943         I (32f), started feeling ppd when baby was 7mo...            0
# 948         I don’t have any help and it’s starting to wei...            0
# 949         I miss my relationship. I miss myself. It feel...            0
#
# [106 rows x 2 columns]

# %%
high_con_filtered = high_con_df[['Unnamed: 1', 'text', 'human_label']]
high_con_filtered.set_index('Unnamed: 1', inplace=True)
high_con_filtered
# Out:
#                                                          text  human_label
# Unnamed: 1
# 175         I’m 4 months PP and I’m still feeling this way...          2.0
# 179         I don’t know where I can vent so posting this ...          0.0
# 195         It’s been 1 yr and I’m still a mess. I just wi...          0.0
# 212         Every since I had my baby i can't stand my MIL...          0.0
# 224         Not sure if this is the right sub for this?\n\...          0.0
# ...                                                       ...          ...
# 890         I have a history of mental health issues (depr...          NaN
# 905         My MIL treated me like shit after I had my 1st...          NaN
# 913         I need some help navigating an issue with my S...          NaN
# 929         I’m at the fucking ledge today…. But I’m talki...          NaN
# 936         This is something that has bugged me for ALONG...          NaN
#
# [87 rows x 2 columns]

# %%
# 将 low_con_filtered 的 'Human_label' 填充到 df 中的 'label' 列
df.loc[low_con_filtered.index, 'label'] = low_con_filtered['human_label']

# 将 high_con_filtered 的 'human_label' 填充到 df 中的 'label' 列
df.loc[high_con_filtered.index, 'label'] = high_con_filtered['human_label']

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 952           952         952
# 953           953         953
# 954           954         954
# 955           955         955
# 956           956         956
#
#                                                   text  label
# 0    First time mom here. My husband recently start...    0.0
# 1    I gained 80 pounds while I was pregnant I went...    1.0
# 2    i’m not usually one to ask for help when i nee...    0.0
# 3    I (31f) and my husband (34m) just had our firs...    0.0
# 4    Hi there, 28F with 2nd baby. 6 weeks PP and wa...    0.0
# ..                                                 ...    ...
# 952  I hit 7 months postpartum tomorrow, and I thin...    0.0
# 953  PPD sucks. I’m overwhelmed by everything. Even...    1.0
# 954  Hello! I’m a first time c section mom who’s 7 ...    0.0
# 955  I finally reached breaking point today. I thin...    0.0
# 956  hi everyone, I was just wondering if anyone ha...    NaN
#
# [957 rows x 4 columns]

# %%
df_train = df[df['label'].notna()]  
df_test = df[df['label'].isna()]   

print("训练集样本数:", df_train.shape[0])
print("测试集样本数:", df_test.shape[0])

print(df_train.head())
print(df_test.head())
# Out:
# 训练集样本数: 773
# 测试集样本数: 184
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 text  label
# 0  First time mom here. My husband recently start...    0.0
# 1  I gained 80 pounds while I was pregnant I went...    1.0
# 2  i’m not usually one to ask for help when i nee...    0.0
# 3  I (31f) and my husband (34m) just had our firs...    0.0
# 4  Hi there, 28F with 2nd baby. 6 weeks PP and wa...    0.0
#      Unnamed: 0.1  Unnamed: 0  \
# 176           176         176
# 181           181         181
# 183           183         183
# 193           193         193
# 194           194         194
#
#                                                   text  label
# 176  Hey all! A few months ago I had posted here as...    NaN
# 181  I know being at daycare (he’s almost 6 months ...    NaN
# 183  So 2 kids 4/1.5 I like to say I’m a pretty goo...    NaN
# 193  I’m struggling with really intense fears revol...    NaN
# 194  I hate my life. I feel like crashing out. I ju...    NaN

# %%
import pandas as pd
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from lightgbm import LGBMClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import StratifiedKFold
import nltk
import spacy

nltk.download('stopwords')
from nltk.corpus import stopwords

nlp = spacy.load('en_core_web_sm')

#df_train.head()
#df_test.head()
df_unlabeled=df_test.copy()

def preprocess_text(text):
    text = text.lower()
    text = ''.join([char for char in text if char.isalpha() or char.isspace()])
    stop_words = set(stopwords.words('english'))
    doc = nlp(text)
    text = ' '.join([token.lemma_ for token in doc if token.text not in stop_words])

    return text
df_train['processed_text'] = df_train['text'].apply(preprocess_text)
df_unlabeled['processed_text'] = df_unlabeled['text'].apply(preprocess_text)
X = df_train['processed_text']
y = df_train['label']
vectorizer = TfidfVectorizer(max_features=5000, ngram_range=(1, 2))  
X_tfidf = vectorizer.fit_transform(X)
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_tfidf, y)
logreg = LogisticRegression(max_iter=1000)
svm = SVC(kernel='linear', random_state=42, probability=True)  # SVM with probability enabled
param_grid_logreg = {'C': [0.1, 1, 10], 'solver': ['liblinear', 'saga']}
grid_search_logreg = GridSearchCV(logreg, param_grid_logreg, cv=5, n_jobs=-1)
grid_search_logreg.fit(X_resampled, y_resampled)
best_logreg = grid_search_logreg.best_estimator_
param_grid_svm = {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf'], 'gamma': ['scale', 'auto']}
grid_search_svm = GridSearchCV(svm, param_grid_svm, cv=5, n_jobs=-1)
grid_search_svm.fit(X_resampled, y_resampled)
best_svm = grid_search_svm.best_estimator_
voting_clf = VotingClassifier(estimators=[('logreg', best_logreg), ('svm', best_svm)], voting='soft')
voting_clf.fit(X_resampled, y_resampled)
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

val_preds, val_true = [], []

for train_idx, val_idx in skf.split(X_resampled, y_resampled):
    X_train, X_val = X_resampled[train_idx], X_resampled[val_idx]
    y_train, y_val = y_resampled.iloc[train_idx], y_resampled.iloc[val_idx]

    voting_clf.fit(X_train, y_train)
    preds = voting_clf.predict(X_val)

    val_preds.extend(preds)
    val_true.extend(y_val)
print(classification_report(val_true, val_preds, digits=4))
X_unlabeled_tfidf = vectorizer.transform(df_unlabeled['processed_text'])
probs = voting_clf.predict_proba(X_unlabeled_tfidf)  # shape: [n_samples, n_classes]
confidences = probs.max(axis=1)
preds = voting_clf.predict(X_unlabeled_tfidf)
df_unlabeled['pseudo_label'] = preds
df_unlabeled['confidence'] = confidences

print(df_unlabeled[['text', 'pseudo_label', 'confidence']].head())
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#               precision    recall  f1-score   support
#
#          0.0     0.8422    0.8768    0.8592       414
#          1.0     0.8675    0.8382    0.8526       414
#          2.0     0.9440    0.9372    0.9406       414
#
#     accuracy                         0.8841      1242
#    macro avg     0.8846    0.8841    0.8841      1242
# weighted avg     0.8846    0.8841    0.8841      1242
#
#                                                   text  pseudo_label  \
# 176  Hey all! A few months ago I had posted here as...           0.0
# 181  I know being at daycare (he’s almost 6 months ...           0.0
# 183  So 2 kids 4/1.5 I like to say I’m a pretty goo...           0.0
# 193  I’m struggling with really intense fears revol...           0.0
# 194  I hate my life. I feel like crashing out. I ju...           1.0
#
#      confidence
# 176    0.886557
# 181    0.424122
# 183    0.677445
# 193    0.541016
# 194    0.713959

# %%
high_conf_df = df_unlabeled[df_unlabeled['confidence'] >= 0.8]
low_conf_df = df_unlabeled[df_unlabeled['confidence'] <= 0.8]
print(f"\nNumber of pseudo-labeled samples with confidence greater than 0.8: {len(high_conf_df)} / {len(df_unlabeled)}")
print(f"\nNumber of pseudo-labeled samples with confidence less than or equal to 0.6: {len(low_conf_df)} / {len(df_unlabeled)}")
# Out:
# Number of pseudo-labeled samples with confidence greater than 0.8: 64 / 184
#
# Number of pseudo-labeled samples with confidence less than or equal to 0.6: 120 / 184

# %%
high_conf_df["pseudo_label"].value_counts()
# Out:
# pseudo_label
# 0.0    36
# 1.0    20
# 2.0     8
# Name: count, dtype: int64

# %%
low_conf_df["pseudo_label"].value_counts()
# Out:
# pseudo_label
# 0.0    65
# 1.0    47
# 2.0     8
# Name: count, dtype: int64

# %%
high_conf_df.to_csv('high_conf_df_v4_1205.csv', index=True)

# %%
low_conf_df.to_csv('low_conf_df_v4_1205.csv', index=True)

# %%
df.to_csv('full_dataset_v4_170labels plus human revise_third.csv', index=True)
