# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

df=pd.read_csv("full_dataset_v2_170labels plus human revise_first.csv")
high_con_df=pd.read_csv('human_review - high_conf_v2_revised.csv')
low_con_df=pd.read_csv('human_review - low_conf_v2_revised.csv')

# %%
high_con_df
# Out:
#     Unnamed: 0  Unnamed: 1                                               text  \
# 0            1         182  I’m 10 weeks postpartum with my 4th baby. Alre...
# 1            2         190  Has anyone taken progesterone (shots,oral,supp...
# 2            3         203  I’m a single mom with a 10 week old and a 4 ye...
# 3            4         226  I’ve never been on psychiatric meds before asi...
# 4            5         242  Hi mums - I’m pretty sure I’m getting hit hard...
# 5            6         251  Did you experience weight gain on Zoloft (Sert...
# 6            7         276  I’ve been doing okay with my ppd since changin...
# 7            8         287  I have an appointment with my OB next week to ...
# 8            9         315  My wife gave birth to a boy 10 days back..me a...
# 9           10         325  I am going insane. Not in a way to hurt my bab...
# 10          11         330  Can I use canesten internal cream 1 week postp...
# 11          12         333  My baby girl looks exactly like her dad. She i...
# 12          13         342  I am currently 3 months pp. I feel like I’m go...
# 13          14         378  I got the prescription in October but held off...
# 14          15         394  Hi...just wondering if anyone has advice or wo...
# 15          16         419  I am currently five days postpartum. Every day...
# 16          17         435  How do you deal with a 6 week newborn when you...
# 17          18         438  Miscarried back in october. How do i know if i...
# 18          19         467  Am supposed to start this Friday but I’m heari...
# 19          20         495  i’m a ftm to a beautiful boy who just turned 1...
# 20          21         506  [Advice](https://www.reddit.com/r/pregnant/?f=...
# 21          22         507  There's a huge huge trigger warning in episode...
# 22          23         509  How does everyone cope with seeing half a head...
# 23          24         516  Hello all! I’m 6 months postpartum and curious...
# 24          25         527  I had a traumatic pregnancy and it was a mirac...
# 25          26         536  My friend is going through PPD and struggling ...
# 26          27         543  If you are in the midst of active PPD, please ...
# 27          28         556  Hello Everyone\n \n\n I have a horrible histor...
# 28          29         567  “If you need anything reach out!” \n \n\n hey ...
# 29          30         583  Trying to survive an abusive relationship whil...
# 30          31         594  I have such a full wonderful life with amazing...
# 31          32         597  Will be starting this medication tonight for P...
# 32          33         613  Just venting as a first time mom- I’m 8 weeks ...
# 33          34         621  I have been suffering from general anxiety dis...
# 34          35         644  Apparently there are clinically proven cases i...
# 35          36         658  Not sure if this is the best place for this, b...
# 36          37         662  My daughter is almost 7 months old and during ...
# 37          38         672  I was suffering from SEVERE PPD/PPA. I went an...
# 38          39         692  Anyone have any experience taking this medicat...
# 39          40         719  My family is begging me to take meds at this p...
# 40          41         721  Did anyone have the sense something was wrong ...
# 41          42         741  TRIGGER WARNING: mention of loss\n \n\n My mar...
# 42          43         761  Idk how I’m feeling towards my partner anymore...
# 43          44         766  I have a three month old boy who I’m recently ...
# 44          45         775  Does the constant fear and irrational thinking...
# 45          46         779  I had to have an emergency c-section 13 days a...
# 46          47         794  I am a week postpartum and am having a really ...
# 47          48         797  So I am currently 10 months postpartum.\n So a...
# 48          49         820  I want to buy my girlfriend some things to hel...
# 49          50         831  Has anyone had success with ECT? I’m 18 weeks ...
# 50          51         833  I just wanna get this off my chest once again ...
# 51          52         870  Hi guys it seems when my sleep gets broken hav...
# 52          53         875  My weird ppd thing is I frequently spiral out ...
# 53          54         880  My fiancé and I have a 6 month old baby girl a...
# 54          55         891  Anyone else ever feel like they just don’t wan...
# 55          56         898  My now ex fiancé (36M) and I (38F) are current...
# 56          57         907  It is red, inflamed. I thought was a zit or an...
# 57          58         909  For anyone who’s experienced postpartum for 1-...
# 58          59         917  Im aftaid im gonna do something really stupid ...
# 59          60         954  Hello! I’m a first time c section mom who’s 7 ...
#
#     label                                     processed_text  pseudo_label  \
# 0     NaN  week postpartum th baby already prozac  buspar...             2
# 1     NaN  anyone take progesterone shotsoralsuppositorye...             0
# 2     NaN  single mom  week old  year old lately night tr...             0
# 3     NaN  never psychiatric med aside adderall sophomore...             0
# 4     NaN  hi mum  pretty sure getting hit hard ppd hard ...             0
# 5     NaN  experience weight gain zoloft sertraline would...             2
# 6     NaN  okay ppd since change medicine september baby ...             2
# 7     NaN  appointment ob next week get medication option...             0
# 8     NaN  wife give birth boy  day backme parent parent ...             0
# 9     NaN  go insane way hurt baby hurt can not baby depe...             0
# 10    NaN  use canesten internal cream  week postpartum c...             0
# 11    NaN  baby girl look exactly like dad absolutely gor...             0
# 12    NaN  currently  month pp feel like go insane think ...             0
# 13    NaN  get prescription october hold take well afraid...             0
# 14    NaN  hijust wonder anyone advice word encouragement...             0
# 15    NaN  currently five day postpartum every day feel t...             0
# 16    NaN       deal  week newborn partner tell go back work             0
# 17    NaN  miscarry back october know pmad flare usual an...             0
# 18    NaN  suppose start friday hear increase anxiety alr...             0
# 19    NaN  ftm beautiful boy turn  shortly go norethindro...             0
# 20    NaN  advicehttpswwwredditcomrpregnantfflairnameaadv...             0
# 21    NaN  huge huge trigger warn episode  wish know good...             2
# 22    NaN  everyone cope see half head hair drain every s...             0
# 23    NaN  hello  month postpartum curious brain fog feel...             0
# 24    NaN  traumatic pregnancy miracle baby girl make pre...             0
# 25    NaN  friend go ppd struggle good friend mean remove...             2
# 26    NaN  midst active ppd please scroll intention worry...             2
# 27    NaN  hello everyone \n \n\n  horrible history pregn...             2
# 28    NaN  need anything reach \n \n\n  hey need somethin...             0
# 29    NaN  try survive abusive relationship postpartum so...             0
# 30    NaN  full wonderful life amazing friend family husb...             2
# 31    NaN  start medication tonight ppd  week postpartum ...             0
# 32    NaN  vent first time mom  week postpartum episode d...             0
# 33    NaN  suffer general anxiety disorder postpartum dep...             0
# 34    NaN  apparently clinically prove case work cure dis...             0
# 35    NaN  sure good place  day postpartum ftm absolutely...             0
# 36    NaN  daughter almost  month old pregnancy  month go...             1
# 37    NaN  suffer severe ppdppa go stay el camino hospita...             0
# 38    NaN  anyone experience take medication wonder side ...             0
# 39    NaN  family beg take med point  take klonipin give ...             0
# 40    NaN  anyone sense something wrong give birth sign t...             0
# 41    NaN  trigger warning mention loss \n \n\n  marriage...             1
# 42    NaN  idk feel towards partner anymore bad guy notic...             0
# 43    NaN  three month old boy recently start fall love h...             2
# 44    NaN  constant fear irrational thinking something ba...             0
# 45    NaN  emergency csection  day ago still can not slee...             0
# 46    NaN  week postpartum really hard time visitor even ...             0
# 47    NaN  currently  month postpartum \n  little recover...             1
# 48    NaN  want buy girlfriend thing help ppd random thin...             0
# 49    NaN  anyone success ect  week postpartum struggle p...             2
# 50    NaN  wanna get chest tonight know post reddit issue...             2
# 51    NaN  hi guy seem sleep get break either tend  year ...             0
# 52    NaN  weird ppd thing frequently spiral control worr...             2
# 53    NaN  fiancé  month old baby girl work north  one we...             0
# 54    NaN  anyone else ever feel like not want anymore no...             0
# 55    NaN  ex fiancé f currently live together long coupl...             2
# 56    NaN  red inflame think zit ingrown hair positive \n...             0
# 57    NaN  anyone experienced postpartum  year first baby...             0
# 58    NaN  aftaid go to something really stupid today cau...             0
# 59    NaN  hello first time c section mom  week pp deal w...             0
#
#     confidence  human label
# 0     0.836133            0
# 1     0.945395            0
# 2     0.900692            0
# 3     0.815370            0
# 4     0.834217            0
# 5     0.812367            0
# 6     0.825896            0
# 7     0.841306            0
# 8     0.864635            2
# 9     0.802440            1
# 10    0.867669            0
# 11    0.820484            0
# 12    0.814193            0
# 13    0.847917            0
# 14    0.835522            0
# 15    0.866823            0
# 16    0.912597            0
# 17    0.832112            0
# 18    0.851269            0
# 19    0.824038            1
# 20    0.842124            0
# 21    0.857676            0
# 22    0.816200            0
# 23    0.844360            0
# 24    0.879549            0
# 25    0.841469            0
# 26    0.869855            0
# 27    0.846789            2
# 28    0.829568            0
# 29    0.880084            0
# 30    0.806135            0
# 31    0.911591            0
# 32    0.844186            0
# 33    0.857151            0
# 34    0.945244            0
# 35    0.800960            0
# 36    0.806244            1
# 37    0.870470            0
# 38    0.908672            0
# 39    0.945232            0
# 40    0.833857            0
# 41    0.830917            1
# 42    0.802700            0
# 43    0.831772            1
# 44    0.845125            0
# 45    0.881490            0
# 46    0.824972            0
# 47    0.803366            0
# 48    0.859320            0
# 49    0.850006            2
# 50    0.814318            0
# 51    0.875497            0
# 52    0.883515            0
# 53    0.840076            1
# 54    0.811989            0
# 55    0.808394            0
# 56    0.811621            0
# 57    0.842035            0
# 58    0.815394            0
# 59    0.878146            0

# %%
low_con_filtered = low_con_df[['Unnamed: 1', 'text', 'human_label']]


low_con_filtered.set_index('Unnamed: 1', inplace=True)

# %%
low_con_filtered
# Out:
#                                                          text  human_label
# Unnamed: 1
# 178         Few weeks ago after DCF was investigating my f...            0
# 184         My oldest is 14 months and I'm currently 8 wee...            1
# 202         The thought I circle a lot is that I wish I co...            2
# 207         Mom looking for a purpose\n\nI am a mom to two...            2
# 213         My ex partner broke if off over the the Christ...            2
# ...                                                       ...          ...
# 897         I, 23f, gave birth to my daughter almost 6 wee...            1
# 903         I’m currently 5 months pp. Am starting to thin...            0
# 927         I’m 6 weeks postpartum and feel like I’m livin...            2
# 942         Today was my first actual session with my ther...            0
# 947         That is it, that is the post. I am 10 weeks po...            2
#
# [100 rows x 2 columns]

# %%
high_con_filtered = high_con_df[['Unnamed: 1', 'text', 'human label']]
high_con_filtered.set_index('Unnamed: 1', inplace=True)
high_con_filtered
# Out:
#                                                          text  human label
# Unnamed: 1
# 182         I’m 10 weeks postpartum with my 4th baby. Alre...            0
# 190         Has anyone taken progesterone (shots,oral,supp...            0
# 203         I’m a single mom with a 10 week old and a 4 ye...            0
# 226         I’ve never been on psychiatric meds before asi...            0
# 242         Hi mums - I’m pretty sure I’m getting hit hard...            0
# 251         Did you experience weight gain on Zoloft (Sert...            0
# 276         I’ve been doing okay with my ppd since changin...            0
# 287         I have an appointment with my OB next week to ...            0
# 315         My wife gave birth to a boy 10 days back..me a...            2
# 325         I am going insane. Not in a way to hurt my bab...            1
# 330         Can I use canesten internal cream 1 week postp...            0
# 333         My baby girl looks exactly like her dad. She i...            0
# 342         I am currently 3 months pp. I feel like I’m go...            0
# 378         I got the prescription in October but held off...            0
# 394         Hi...just wondering if anyone has advice or wo...            0
# 419         I am currently five days postpartum. Every day...            0
# 435         How do you deal with a 6 week newborn when you...            0
# 438         Miscarried back in october. How do i know if i...            0
# 467         Am supposed to start this Friday but I’m heari...            0
# 495         i’m a ftm to a beautiful boy who just turned 1...            1
# 506         [Advice](https://www.reddit.com/r/pregnant/?f=...            0
# 507         There's a huge huge trigger warning in episode...            0
# 509         How does everyone cope with seeing half a head...            0
# 516         Hello all! I’m 6 months postpartum and curious...            0
# 527         I had a traumatic pregnancy and it was a mirac...            0
# 536         My friend is going through PPD and struggling ...            0
# 543         If you are in the midst of active PPD, please ...            0
# 556         Hello Everyone\n \n\n I have a horrible histor...            2
# 567         “If you need anything reach out!” \n \n\n hey ...            0
# 583         Trying to survive an abusive relationship whil...            0
# 594         I have such a full wonderful life with amazing...            0
# 597         Will be starting this medication tonight for P...            0
# 613         Just venting as a first time mom- I’m 8 weeks ...            0
# 621         I have been suffering from general anxiety dis...            0
# 644         Apparently there are clinically proven cases i...            0
# 658         Not sure if this is the best place for this, b...            0
# 662         My daughter is almost 7 months old and during ...            1
# 672         I was suffering from SEVERE PPD/PPA. I went an...            0
# 692         Anyone have any experience taking this medicat...            0
# 719         My family is begging me to take meds at this p...            0
# 721         Did anyone have the sense something was wrong ...            0
# 741         TRIGGER WARNING: mention of loss\n \n\n My mar...            1
# 761         Idk how I’m feeling towards my partner anymore...            0
# 766         I have a three month old boy who I’m recently ...            1
# 775         Does the constant fear and irrational thinking...            0
# 779         I had to have an emergency c-section 13 days a...            0
# 794         I am a week postpartum and am having a really ...            0
# 797         So I am currently 10 months postpartum.\n So a...            0
# 820         I want to buy my girlfriend some things to hel...            0
# 831         Has anyone had success with ECT? I’m 18 weeks ...            2
# 833         I just wanna get this off my chest once again ...            0
# 870         Hi guys it seems when my sleep gets broken hav...            0
# 875         My weird ppd thing is I frequently spiral out ...            0
# 880         My fiancé and I have a 6 month old baby girl a...            1
# 891         Anyone else ever feel like they just don’t wan...            0
# 898         My now ex fiancé (36M) and I (38F) are current...            0
# 907         It is red, inflamed. I thought was a zit or an...            0
# 909         For anyone who’s experienced postpartum for 1-...            0
# 917         Im aftaid im gonna do something really stupid ...            0
# 954         Hello! I’m a first time c section mom who’s 7 ...            0

# %%
# 将 low_con_filtered 的 'Human_label' 填充到 df 中的 'label' 列
df.loc[low_con_filtered.index, 'label'] = low_con_filtered['human_label']

# 将 high_con_filtered 的 'human_label' 填充到 df 中的 'label' 列
df.loc[high_con_filtered.index, 'label'] = high_con_filtered['human label']

# %%
df
# Out:
#      Unnamed: 0                                               text  label
# 0             0  First time mom here. My husband recently start...    0.0
# 1             1  I gained 80 pounds while I was pregnant I went...    1.0
# 2             2  i’m not usually one to ask for help when i nee...    0.0
# 3             3  I (31f) and my husband (34m) just had our firs...    0.0
# 4             4  Hi there, 28F with 2nd baby. 6 weeks PP and wa...    0.0
# ..          ...                                                ...    ...
# 952         952  I hit 7 months postpartum tomorrow, and I thin...    0.0
# 953         953  PPD sucks. I’m overwhelmed by everything. Even...    1.0
# 954         954  Hello! I’m a first time c section mom who’s 7 ...    0.0
# 955         955  I finally reached breaking point today. I thin...    0.0
# 956         956  hi everyone, I was just wondering if anyone ha...    NaN
#
# [957 rows x 3 columns]

# %%
df_train = df[df['label'].notna()]  
df_test = df[df['label'].isna()]    


print("训练集样本数:", df_train.shape[0])
print("测试集样本数:", df_test.shape[0])


print(df_train.head())
print(df_test.head())
# Out:
# 训练集样本数: 601
# 测试集样本数: 356
#    Unnamed: 0                                               text  label
# 0           0  First time mom here. My husband recently start...    0.0
# 1           1  I gained 80 pounds while I was pregnant I went...    1.0
# 2           2  i’m not usually one to ask for help when i nee...    0.0
# 3           3  I (31f) and my husband (34m) just had our firs...    0.0
# 4           4  Hi there, 28F with 2nd baby. 6 weeks PP and wa...    0.0
#      Unnamed: 0                                               text  label
# 173         173  Has anyone been hospitalised in a (mbu) mother...    NaN
# 175         175  I’m 4 months PP and I’m still feeling this way...    NaN
# 176         176  Hey all! A few months ago I had posted here as...    NaN
# 179         179  I don’t know where I can vent so posting this ...    NaN
# 181         181  I know being at daycare (he’s almost 6 months ...    NaN

# %%
df_unlabeled
# Out:
#      Unnamed: 0                                               text  label  \
# 173         173  Has anyone been hospitalised in a (mbu) mother...    NaN
# 175         175  I’m 4 months PP and I’m still feeling this way...    NaN
# 176         176  Hey all! A few months ago I had posted here as...    NaN
# 179         179  I don’t know where I can vent so posting this ...    NaN
# 181         181  I know being at daycare (he’s almost 6 months ...    NaN
# ..          ...                                                ...    ...
# 946         946  To preface, I never intended to be a parent, I...    NaN
# 948         948  I don’t have any help and it’s starting to wei...    NaN
# 949         949  I miss my relationship. I miss myself. It feel...    NaN
# 951         951  I feel so bad. She has colic and was having a ...    NaN
# 956         956  hi everyone, I was just wondering if anyone ha...    NaN
#
#                                         processed_text  pseudo_label  \
# 173  anyone hospitalise mbu mother baby unit \n\n f...           0.0
# 175    month pp still feel way lose entire identity...           1.0
# 176  hey month ago post ask anyone experience zurzu...           0.0
# 179  not know vent post herei baby wks ago feel rag...           0.0
# 181  know daycare almost   month even   full month ...           1.0
# ..                                                 ...           ...
# 946  preface never intend parent struggle mental he...           1.0
# 948  not help starting weigh baby   month old mil a...           1.0
# 949  miss relationship miss feel like everything th...           0.0
# 951  feel bad colic tough time set sob could not an...           2.0
# 956  hi everyone wonder anyone experience cope mech...           2.0
#
#      confidence
# 173    0.542298
# 175    0.802369
# 176    0.705094
# 179    0.806413
# 181    0.676730
# ..          ...
# 946    0.751007
# 948    0.458577
# 949    0.581253
# 951    0.689192
# 956    0.631802
#
# [356 rows x 6 columns]

# %%
import pandas as pd
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from lightgbm import LGBMClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import StratifiedKFold
import nltk
import spacy


nltk.download('stopwords')
from nltk.corpus import stopwords


nlp = spacy.load('en_core_web_sm')

#df_train.head()
#df_test.head()
df_unlabeled=df_test.copy()


def preprocess_text(text):

    text = text.lower()


    text = ''.join([char for char in text if char.isalpha() or char.isspace()])


    stop_words = set(stopwords.words('english'))
    doc = nlp(text)
    text = ' '.join([token.lemma_ for token in doc if token.text not in stop_words])

    return text

df_train['processed_text'] = df_train['text'].apply(preprocess_text)
df_unlabeled['processed_text'] = df_unlabeled['text'].apply(preprocess_text)

X = df_train['processed_text']
y = df_train['label']

vectorizer = TfidfVectorizer(max_features=5000, ngram_range=(1, 2))
X_tfidf = vectorizer.fit_transform(X)

smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_tfidf, y)

logreg = LogisticRegression(max_iter=1000)
svm = SVC(kernel='linear', random_state=42, probability=True)  # SVM with probability enabled

param_grid_logreg = {'C': [0.1, 1, 10], 'solver': ['liblinear', 'saga']}
grid_search_logreg = GridSearchCV(logreg, param_grid_logreg, cv=5, n_jobs=-1)
grid_search_logreg.fit(X_resampled, y_resampled)
best_logreg = grid_search_logreg.best_estimator_

param_grid_svm = {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf'], 'gamma': ['scale', 'auto']}
grid_search_svm = GridSearchCV(svm, param_grid_svm, cv=5, n_jobs=-1)
grid_search_svm.fit(X_resampled, y_resampled)
best_svm = grid_search_svm.best_estimator_

voting_clf = VotingClassifier(estimators=[('logreg', best_logreg), ('svm', best_svm)], voting='soft')

voting_clf.fit(X_resampled, y_resampled)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

val_preds, val_true = [], []

for train_idx, val_idx in skf.split(X_resampled, y_resampled):
    X_train, X_val = X_resampled[train_idx], X_resampled[val_idx]
    y_train, y_val = y_resampled.iloc[train_idx], y_resampled.iloc[val_idx]

    voting_clf.fit(X_train, y_train)
    preds = voting_clf.predict(X_val)

    val_preds.extend(preds)
    val_true.extend(y_val)

print(classification_report(val_true, val_preds, digits=4))

X_unlabeled_tfidf = vectorizer.transform(df_unlabeled['processed_text'])

probs = voting_clf.predict_proba(X_unlabeled_tfidf)  # shape: [n_samples, n_classes]

confidences = probs.max(axis=1)

preds = voting_clf.predict(X_unlabeled_tfidf)

df_unlabeled['pseudo_label'] = preds
df_unlabeled['confidence'] = confidences

print(df_unlabeled[['text', 'pseudo_label', 'confidence']].head())
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#               precision    recall  f1-score   support
#
#          0.0     0.8669    0.8511    0.8589       329
#          1.0     0.8702    0.8967    0.8832       329
#          2.0     0.9631    0.9514    0.9572       329
#
#     accuracy                         0.8997       987
#    macro avg     0.9001    0.8997    0.8998       987
# weighted avg     0.9001    0.8997    0.8998       987
#
#                                                   text  pseudo_label  \
# 173  Has anyone been hospitalised in a (mbu) mother...           0.0
# 175  I’m 4 months PP and I’m still feeling this way...           1.0
# 176  Hey all! A few months ago I had posted here as...           0.0
# 179  I don’t know where I can vent so posting this ...           0.0
# 181  I know being at daycare (he’s almost 6 months ...           1.0
#
#      confidence
# 173    0.542298
# 175    0.802369
# 176    0.705094
# 179    0.806413
# 181    0.676730

# %%
high_conf_df = df_unlabeled[df_unlabeled['confidence'] >= 0.8]
low_conf_df = df_unlabeled[df_unlabeled['confidence'] <= 0.6]
print(f"\nNumber of pseudo-labeled samples with confidence greater than 0.8: {len(high_conf_df)} / {len(df_unlabeled)}")
print(f"\nNumber of pseudo-labeled samples with confidence less than or equal to 0.6: {len(low_conf_df)} / {len(df_unlabeled)}")
# Out:
# Number of pseudo-labeled samples with confidence greater than 0.8: 87 / 356
#
# Number of pseudo-labeled samples with confidence less than or equal to 0.6: 106 / 356

# %%
high_conf_df["pseudo_label"].value_counts()
# Out:
# pseudo_label
# 0.0    56
# 1.0    28
# 2.0     3
# Name: count, dtype: int64

# %%
low_conf_df["pseudo_label"].value_counts()
# Out:
# pseudo_label
# 0.0    45
# 1.0    43
# 2.0    18
# Name: count, dtype: int64

# %%
high_conf_df.to_csv('high_conf_df_v3_0905.csv', index=True)

# %%
low_conf_df.to_csv('low_conf_df_v3_0905.csv', index=True)

# %%
df.to_csv('full_dataset_v3_170labels plus human revise_second.csv', index=True)
